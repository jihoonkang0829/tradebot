# %%
import gym_anytrading
from gym_anytrading.envs import StocksEnv, Actions, Positions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from assets.gru import GRU

# %%
def my_calculate_reward(self, action):
    step_reward = 0

    current_price = self.prices[self._current_tick]
    if action == Actions.Buy.value:
        step_reward = current_price
    elif action == Actions.Sell.value:
        step_reward = -1 * current_price
    return step_reward


def mystep(self, action):
    self._done = False
    self._current_tick += 1
    if(action == 2):
        if self._position == Positions.Long:
            action = Actions.Buy.value
        elif self._position == Positions.Short:
            action = Actions.Sell.value
            
    if (self._current_tick) == self._end_tick:
        self._done = True

    step_reward = self._calculate_reward(action)
    self._total_reward += step_reward

    self._update_profit(action)

    if action == Actions.Buy.value:
        self._position = Positions.Long
    elif action == Actions.Sell.value:
        self._position = Positions.Short
    self._last_trade_tick = self._current_tick

    self._position_history.append(self._position)
    observation = self._get_observation()
    info = dict(
        total_reward = self._total_reward,
        total_profit = self._total_profit,
        position = self._position.value
    )
    self._update_history(info)

    return observation, step_reward, self._done, info

def my_update_profit(self, action):
    current_price = self.prices[self._current_tick]
    if action == Actions.Buy.value:
        self._total_profit = self._total_profit * (1+ (current_price * 10) )
    elif action == Actions.Sell.value:
        self._total_profit = self._total_profit * (1- (current_price * 10) )
        
def my_process_data(self):
    prices = self.df.loc[:, 'Close'].to_numpy()
    
    prices[self.frame_bound[0] - self.window_size]  # validate index (TODO: Improve validation)
    prices = prices[self.frame_bound[0]-self.window_size:self.frame_bound[1]]
    
    volumes = self.df.loc[:, 'volume'].to_numpy()
    
    volumes[self.frame_bound[0] - self.window_size]  # validate index (TODO: Improve validation)
    volumes = volumes[self.frame_bound[0]-self.window_size:self.frame_bound[1]]

    signal_features = np.column_stack((prices, volumes))

    return prices, signal_features

class MyFuturesEnv(StocksEnv):
    _calculate_reward = my_calculate_reward
    step = mystep
    _update_profit = my_update_profit
    _process_data = my_process_data

# %%
hourdata = pd.read_csv('./assets/BTCUSDTMIN.csv', usecols=['unix', 'close', 'Volume USDT'])
# hourdata = hourdata.to_numpy()
# hourdata[hourdata == 0] = 0.0000000000000001
# hourcalc = hourdata[:, 1:3]
# hourcalc = (np.log(hourcalc) - np.log(np.roll(hourcalc, -1, axis =0)))[:-1]
# hourdata = hourdata[:-1]
# hourdata[:, 1:3] = hourcalc
# hourdf = pd.DataFrame(data=hourdata, columns=['unix', 'Close', 'volume'])

# plt.plot(hourdf['Close'])
hourdata
# Out:
#                  unix     close   Volume USDT
# 0       1599870780000  10344.35  4.055306e+05
# 1       1599870840000  10342.11  9.660535e+05
# 2       1599870900000  10341.14  7.519285e+05
# 3       1599870960000  10335.43  7.778215e+05
# 4       1599871020000  10337.94  3.173629e+05
# ...               ...       ...           ...
# 289409  1617235320000  59046.01  2.204962e+07
# 289410  1617235380000  59166.94  2.333094e+07
# 289411  1617235440000  59173.75  1.977586e+07
# 289412  1617235500000  59076.10  1.075253e+07
# 289413  1617235560000  59166.60  7.446040e+06
#
# [289414 rows x 3 columns]

# %%
model = torch.load('assets/gru_classification_model.pt')

# %%
env = MyFuturesEnv(df = hourdf, window_size = 15, frame_bound = (int(0.8 * len(hourdf) / 10) * 10, len(hourdf) ))
observation = env.reset()
while True:
    observation = observation[np.newaxis, ...]
    print(observation.shape)
    observation = torch.from_numpy(observation).float()
    action = model(observation)
    observation, reward, done, info = env.step(action)

    if done:
        print("info:", info)
        break
# Out:
# (1, 15, 2)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-51-ead51f07dfda> in <module>
#       5     print(observation.shape)
#       6     observation = torch.from_numpy(observation).float()
# ----> 7     action = model(observation)
#       8     observation, reward, done, info = env.step(action)
#       9
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/tradebot/assets/gru.py in forward(self, x)
#      12
#      13     def forward(self, x):
# ---> 14         h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().cuda()
#      15         out, (hn) = self.gru(x, (h0.detach()))
#      16         out = out[:, -1, :]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     162                 "multiprocessing, you must use the 'spawn' start method")
#     163         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 164             raise AssertionError("Torch not compiled with CUDA enabled")
#     165         if _cudart is None:
#     166             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
plt.figure(figsize=(16, 6))
env.render_all()
plt.show()
net_worth = pd.Series(env.history['total_profit'])
print(net_worth.plot())
