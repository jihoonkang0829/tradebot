# %%
# from assets.credentials import *
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
import sys
sys.path
# Out:
# ['/Users/jihoonkang/tradebot',
#  '/Users/jihoonkang/.vscode/extensions/ms-toolsai.jupyter-2020.12.414227025/pythonFiles',
#  '/Users/jihoonkang/.vscode/extensions/ms-toolsai.jupyter-2020.12.414227025/pythonFiles/lib/python',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/jihoonkang/Library/Python/3.9/lib/python/site-packages',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/extensions',
#  '/Users/jihoonkang/.ipython']

# %%
# Credentials setting
import alpaca_trade_api as tradeapi
import os

os.environ['APCA_API_KEY_ID'] = ALPACA_KEY
os.environ['APCA_API_SECRET_KEY'] = ALPACA_SECRET
os.environ['ALPHAVANTAGE_API_KEY'] = ALPHA_VANTAGE_KEY
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7f98a836032c> in <module>
#       1 # Credentials setting
# ----> 2 import alpaca_trade_api as tradeapi
#       3 import os
#       4
#       5 os.environ['APCA_API_KEY_ID'] = ALPACA_KEY
#
# ModuleNotFoundError: No module named 'alpaca_trade_api'

# %%
# Create LSTM Model
torch.manual_seed(1)

# %%
# Alpaca account credentials


api = tradeapi.REST()
account = api.get_account()
account.buying_power
# Out:
# '0'

# %%
from alpha_vantage.timeseries import TimeSeries as ts

ts = ts(key=ALPHA_VANTAGE_KEY, output_format = 'pandas', indexing_type = 'date')
data, meta_data = ts.get_intraday(symbol = 'AAPL', interval = '1min', outputsize = 'full')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-12-31 20:00:00   132.70   132.72  132.70    132.71     5832.0
# 2020-12-31 19:59:00   132.71   132.72  132.70    132.72     6676.0
# 2020-12-31 19:58:00   132.71   132.71  132.70    132.70     6441.0
# 2020-12-31 19:57:00   132.72   132.72  132.71    132.71     2468.0
# 2020-12-31 19:56:00   132.70   132.70  132.70    132.70     3203.0
# ...                      ...      ...     ...       ...        ...
# 2020-12-21 04:05:00   127.12   127.12  127.00    127.00     2047.0
# 2020-12-21 04:04:00   127.30   127.30  127.10    127.10     3888.0
# 2020-12-21 04:03:00   127.07   127.40  127.07    127.30     3378.0
# 2020-12-21 04:02:00   126.95   126.95  126.90    126.92     1626.0
# 2020-12-21 04:01:00   127.10   127.50  126.00    126.95    19294.0
#
# [6582 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2020-12-31 20:00:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
assets = api.list_assets()
assets
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ae4f5f76-48ee-49f2-83f7-49ae449f211d',
#      'marginable': True,
#      'name': 'ClearBridge MLP and Midstream Fund Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4c896ed8-38e1-4701-8225-c6f0003c2f08',
#      'marginable': True,
#      'name': 'Sinopec Shanghai Petrochemical Co., Ltd.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SHI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '3b206368-296a-4ce5-aac2-e88b57ec34ec',
#      'marginable': True,
#      'name': 'Cohen & Steers  Infrastructure Fund, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UTF',
# ...
